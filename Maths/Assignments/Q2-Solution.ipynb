# %%
import numpy as np
def getRandomMatrix():
    return np.around(np.random.randn(3,3),4)
def getLUMatrices(A):
    n = A.shape[0]
    U = A.copy()
    L = np.eye(n, dtype=np.double)
    for i in range(n):
        factor = U[i+1:, i] / U[i, i]
        L[i+1:, i] = factor
        U[i+1:] -= factor[:, np.newaxis] * U[i]
    return L, U
def generate_diagonally_dominant_matrix():
    A = getRandomMatrix()
    D = np.diag(np.abs(A)) # Find diagonal coefficients
    S = np.sum(np.abs(A), axis=1) - D # Find row sum without diagonal
    L,U = getLUMatrices(A)
    C = -np.linalg.inv(np.identity(3)+L)*U
    if np.all(D > S) and np.linalg.norm(C,'fro') < 1:
        return A
    else:
        return generate_diagonally_dominant_matrix()
def testConvrgence(A):
    L,U = getLUMatrices(A)
    C = -np.linalg.inv(np.identity(3)+L)*U
    print("Test for convergence::",np.linalg.norm(C,'fro') < 1)
    
A = generate_diagonally_dominant_matrix()
b = np.random.rand(3,1)
print("Random Generated Co-efficient matrix is:\n",A)
print("Random Generated Vector is:\n",b)
# Out:
# Random Generated Co-efficient matrix is:
#  [[-1.623   0.8066 -0.5093]
#  [-0.1561  0.6837 -0.2813]
#  [ 0.0026  0.418  -0.5089]]
# Random Generated Vector is:
#  [[0.08866367]
#  [0.38132434]
#  [0.08682732]]

# %%
def GaussJacobiSolution(A,b):
    ITERATION_LIMIT = 1000

    # prints the system
    print("System of equations to be solved using Gauss Jacobi:")
    for i in range(A.shape[0]):
        row = ["{}x{}".format(A[i, j], j + 1) for j in range(A.shape[1])]
        print(" + ".join(row), "=", b[i])
    print()

    x = np.zeros_like(b)
    for it_count in range(ITERATION_LIMIT):
        if it_count != 0:
            print("Iteration {0}: {1}".format(it_count, x))
        x_new = np.zeros_like(x)

        for i in range(A.shape[0]):
            s1 = np.dot(A[i, :i], x[:i])
            s2 = np.dot(A[i, i + 1:], x[i + 1:])
            x_new[i] = (b[i] - s1 - s2) / A[i, i]
            if x_new[i] == x_new[i-1]:
                break

        if np.allclose(x, x_new, atol=0.01, rtol=0.):
            break

        x = x_new

    print("Solution:")
    print(x)
    error = np.dot(A, x) - b
    print("Error:")
    print(error)

# %%
def GaussSeidelSolution(A,b):
    ITERATION_LIMIT = 1000

    # prints the system
    print("System of equations to be solved using Gauss ssiedel:")
    for i in range(A.shape[0]):
        row = ["{}x{}".format(A[i, j], j + 1) for j in range(A.shape[1])]
        print("[{}] = [{}]".format(" + ".join(row), b[i]))

    x = np.zeros_like(b)
    for it_count in range(1, ITERATION_LIMIT):
        x_new = np.zeros_like(x)
        print("Iteration {0}: {1}".format(it_count, x))
        for i in range(A.shape[0]):
            s1 = np.dot(A[i, :i], x_new[:i])
            s2 = np.dot(A[i, i + 1 :], x[i + 1 :])
            x_new[i] = (b[i] - s1 - s2) / A[i, i]
        if np.allclose(x, x_new, rtol=0.01):
            break
        x = x_new

    print("Solution: {0}".format(x))
    error = np.dot(A, x) - b
    print("Error: {0}".format(error))

# %%
GaussJacobiSolution(A,b)
# Out:
# System of equations to be solved using Gauss Jacobi:
# -1.623x1 + 0.8066x2 + -0.5093x3 = [0.08866367]
# -0.1561x1 + 0.6837x2 + -0.2813x3 = [0.38132434]
# 0.0026x1 + 0.418x2 + -0.5089x3 = [0.08682732]
#
# Iteration 1: [[-0.0546295 ]
#  [ 0.55773635]
#  [-0.17061764]]
# Iteration 2: [[0.2760949 ]
#  [0.475065  ]
#  [0.28721643]]
# Iteration 3: [[0.09133976]
#  [0.73894506]
#  [0.22100157]]
# Iteration 4: [[0.24326144]
#  [0.66951912]
#  [0.43680331]]
# Iteration 5: [[0.14103914]
#  [0.79299433]
#  [0.38055444]]
# Iteration 6: [[0.22005495]
#  [0.74651238]
#  [0.48145219]]
# Iteration 7: [[0.16529243]
#  [0.80606614]
#  [0.44367657]]
# Iteration 8: [[0.20674356]
#  [0.77802064]
#  [0.49231301]]
# Iteration 9: [[0.17754329]
#  [0.80749549]
#  [0.46948879]]
# Iteration 10: [[0.199354  ]
#  [0.79143783]
#  [0.49354964]]
# Iteration 11: [[0.18382332]
#  [0.80631712]
#  [0.48047164]]
# Iteration 12: [[0.19532194]
#  [0.79739043]
#  [0.49261384]]
# Solution:
# [[0.19532194]
#  [0.79739043]
#  [0.49261384]]
# Error:
# [[-0.01338429]
#  [-0.00521053]
#  [-0.00370146]]

# %%
GaussSeidelSolution(A,b)
# Out:
# System of equations to be solved using Gauss Jacobi:
# [-1.623x1 + 0.8066x2 + -0.5093x3] = [[0.08866367]]
# [-0.1561x1 + 0.6837x2 + -0.2813x3] = [[0.38132434]]
# [0.0026x1 + 0.418x2 + -0.5089x3] = [[0.08682732]]
# Iteration 1: [[0.]
#  [0.]
#  [0.]]
# Iteration 2: [[-0.0546295 ]
#  [ 0.54526353]
#  [ 0.27697152]]
# Iteration 3: [[0.12944196]
#  [0.70124663]
#  [0.40603326]]
# Iteration 4: [[0.1664628 ]
#  [0.76279997]
#  [0.45678105]]
# Iteration 5: [[0.18112889]
#  [0.78702804]
#  [0.47675642]]
# Iteration 6: [[0.18690148]
#  [0.79656464]
#  [0.48461908]]
# Iteration 7: [[0.18917367]
#  [0.80031841]
#  [0.48771396]]
# Solution: [[0.18917367]
#  [0.80031841]
#  [0.48771396]]
# Error: [[ 0.00145157]
#  [-0.00087059]
#  [ 0.        ]]

# %%
#Generate Non Diagonally Dominant Random Matrix 
def generateNDD():
    A = getRandomMatrix()
    D = np.diag(np.abs(A)) # Find diagonal coefficients
    S = np.sum(np.abs(A), axis=1) - D # Find row sum without diagonal
    if all(D < S):
        return A
    else:
        return generateNDD()
def is_pos_def(x):
    return np.all(np.linalg.eigvals(x) > 0)

# %%
AA = generateNDD()
if is_pos_def(AA):
    AA = generateNDD()
print("Non Diagonally Dominant Random Matrix is:\n",AA)
# Out:
# Non Diagonally Dominant Random Matrix is:
#  [[ 1.3691 -2.0383  0.5169]
#  [ 0.6485  0.2693 -0.303 ]
#  [ 2.0148  1.2534 -0.1515]]

# %%
def NDDSolutionAttempt(AA,b):
    ITERATION_LIMIT = 1000

    # prints the system
    print("System of equations to be solved using Non Diagonally Dominant Random Matrix:")
    for i in range(AA.shape[0]):
        row = ["{}x{}".format(AA[i, j], j + 1) for j in range(AA.shape[1])]
        print(" + ".join(row), "=", b[i])
    print()

    x = np.zeros_like(b)
    for it_count in range(ITERATION_LIMIT):
        if it_count != 0:
            print("Iteration {0}: {1}".format(it_count, x))
        x_new = np.zeros_like(x)

        for i in range(AA.shape[0]):
            s1 = np.dot(AA[i, :i], x[:i])
            s2 = np.dot(AA[i, i + 1:], x[i + 1:])
            x_new[i] = (b[i] - s1 - s2) / AA[i, i]
            if x_new[i] == x_new[i-1]:
                break

        if np.allclose(x, x_new, atol=0.01, rtol=0.):
            break

        x = x_new

    print("Solution:")
    print(x)
    error = np.dot(AA, x) - b
    print("Error:")
    print(error)

# %%
NDDSolutionAttempt(AA,b)
# Out:
# 00222316e+269]
#  [9.43596929e+269]
#  [2.87786922e+270]]
# Iteration 540: [[3.18284288e+269]
#  [2.99665875e+270]
#  [9.13948721e+270]]
# Iteration 541: [[1.01080170e+270]
#  [9.51673696e+270]
#  [2.90250249e+271]]
# Iteration 542: [[3.21008662e+270]
#  [3.02230881e+271]
#  [9.21771707e+271]]
# Iteration 543: [[1.01945373e+271]
#  [9.59819590e+271]
#  [2.92734661e+272]]
# Iteration 544: [[3.23756340e+271]
#  [3.04817842e+272]
#  [9.29661657e+272]]
# Iteration 545: [[1.02817981e+272]
#  [9.68035216e+272]
#  [2.95240337e+273]]
# Iteration 546: [[3.26527556e+272]
#  [3.07426944e+273]
#  [9.37619146e+273]]
# Iteration 547: [[1.03698053e+273]
#  [9.76321163e+273]
#  [2.97767461e+274]]
# Iteration 548: [[3.29322489e+273]
#  [3.10058381e+274]
#  [9.45644741e+274]]
# Iteration 549: [[1.04585663e+274]
#  [9.84678029e+274]
#  [3.00316218e+275]]
# Iteration 550: [[3.32141331e+274]
#  [3.12712342e+275]
#  [9.53739034e+275]]
# Iteration 551: [[1.05480871e+275]
#  [9.93106431e+275]
#  [3.02886789e+276]]
# Iteration 552: [[3.34984316e+275]
#  [3.15389018e+276]
#  [9.61902614e+276]]
# Iteration 553: [[1.06383737e+276]
#  [1.00160698e+277]
#  [3.05479363e+277]]
# Iteration 554: [[3.37851636e+276]
#  [3.18088606e+277]
#  [9.70136065e+277]]
# Iteration 555: [[1.07294335e+277]
#  [1.01018028e+278]
#  [3.08094130e+278]]
# Iteration 556: [[3.40743486e+277]
#  [3.20811302e+278]
#  [9.78439992e+278]]
# Iteration 557: [[1.08212728e+278]
#  [1.01882697e+279]
#  [3.10731276e+279]]
# Iteration 558: [[3.43660100e+278]
#  [3.23557302e+279]
#  [9.86815001e+279]]
# Iteration 559: [[1.09138978e+279]
#  [1.02754767e+280]
#  [3.13390996e+280]]
# Iteration 560: [[3.46601680e+279]
#  [3.26326807e+280]
#  [9.95261692e+280]]
# Iteration 561: [[1.10073159e+280]
#  [1.03634301e+281]
#  [3.16073483e+281]]
# Iteration 562: [[3.49568428e+280]
#  [3.29120018e+281]
#  [1.00378068e+282]]
# Iteration 563: [[1.11015337e+281]
#  [1.04521364e+282]
#  [3.18778929e+282]]
# Iteration 564: [[3.52560578e+281]
#  [3.31937137e+282]
#  [1.01237260e+283]]
# Iteration 565: [[1.11965576e+282]
#  [1.05416020e+283]
#  [3.21507533e+283]]
# Iteration 566: [[3.55578342e+282]
#  [3.34778369e+283]
#  [1.02103805e+284]]
# Iteration 567: [[1.12923952e+283]
#  [1.06318334e+284]
#  [3.24259493e+284]]
# Iteration 568: [[3.58621927e+283]
#  [3.37643922e+284]
#  [1.02977767e+285]]
# Iteration 569: [[1.13890531e+284]
#  [1.07228371e+285]
#  [3.27035008e+285]]
# Iteration 570: [[3.61691570e+284]
#  [3.40534001e+285]
#  [1.03859211e+286]]
# Iteration 571: [[1.14865382e+285]
#  [1.08146198e+286]
#  [3.29834280e+286]]
# Iteration 572: [[3.64787491e+285]
#  [3.43448819e+286]
#  [1.04748199e+287]]
# Iteration 573: [[1.15848578e+286]
#  [1.09071880e+287]
#  [3.32657514e+287]]
# Iteration 574: [[3.67909904e+286]
#  [3.46388587e+287]
#  [1.05644796e+288]]
# Iteration 575: [[1.16840190e+287]
#  [1.10005487e+288]
#  [3.35504912e+288]]
# Iteration 576: [[3.71059047e+287]
#  [3.49353517e+288]
#  [1.06549068e+289]]
# Iteration 577: [[1.17840289e+288]
#  [1.10947084e+289]
#  [3.38376683e+289]]
# Iteration 578: [[3.74235149e+288]
#  [3.52343826e+289]
#  [1.07461080e+290]]
# Iteration 579: [[1.18848949e+289]
#  [1.11896741e+290]
#  [3.41273036e+290]]
# Iteration 580: [[3.77438430e+289]
#  [3.55359731e+290]
#  [1.08380899e+291]]
# Iteration 581: [[1.19866243e+290]
#  [1.12854527e+291]
#  [3.44194179e+291]]
# Iteration 582: [[3.80669133e+290]
#  [3.58401450e+291]
#  [1.09308591e+292]]
# Iteration 583: [[1.20892243e+291]
#  [1.13820511e+292]
#  [3.47140326e+292]]
# Iteration 584: [[3.83927492e+291]
#  [3.61469205e+292]
#  [1.10244223e+293]]
# Iteration 585: [[1.21927026e+292]
#  [1.14794763e+293]
#  [3.50111691e+293]]
# Iteration 586: [[3.87213737e+292]
#  [3.64563219e+293]
#  [1.11187864e+294]]
# Iteration 587: [[1.22970668e+293]
#  [1.15777355e+294]
#  [3.53108490e+294]]
# Iteration 588: [[3.90528111e+293]
#  [3.67683716e+294]
#  [1.12139582e+295]]
# Iteration 589: [[1.24023241e+294]
#  [1.16768357e+295]
#  [3.56130939e+295]]
# Iteration 590: [[3.93870859e+294]
#  [3.70830922e+295]
#  [1.13099446e+296]]
# Iteration 591: [[1.25084824e+295]
#  [1.17767841e+296]
#  [3.59179260e+296]]
# Iteration 592: [[3.97242214e+295]
#  [3.74005069e+296]
#  [1.14067526e+297]]
# Iteration 593: [[1.26155494e+296]
#  [1.18775881e+297]
#  [3.62253673e+297]]
# Iteration 594: [[4.00642428e+296]
#  [3.77206383e+297]
#  [1.15043893e+298]]
# Iteration 595: [[1.27235328e+297]
#  [1.19792549e+298]
#  [3.65354401e+298]]
# Iteration 596: [[4.04071749e+297]
#  [3.80435100e+298]
#  [1.16028617e+299]]
# Iteration 597: [[1.28324405e+298]
#  [1.20817919e+299]
#  [3.68481670e+299]]
# Iteration 598: [[4.07530420e+298]
#  [3.83691454e+299]
#  [1.17021770e+300]]
# Iteration 599: [[1.29422805e+299]
#  [1.21852066e+300]
#  [3.71635708e+300]]
# Iteration 600: [[4.11018696e+299]
#  [3.86975680e+300]
#  [1.18023424e+301]]
# Iteration 601: [[1.30530605e+300]
#  [1.22895065e+301]
#  [3.74816742e+301]]
# Iteration 602: [[4.14536833e+300]
#  [3.90288017e+301]
#  [1.19033651e+302]]
# Iteration 603: [[1.31647888e+301]
#  [1.23946992e+302]
#  [3.78025005e+302]]
# Iteration 604: [[4.18085081e+301]
#  [3.93628707e+302]
#  [1.20052525e+303]]
# Iteration 605: [[1.32774735e+302]
#  [1.25007922e+303]
#  [3.81260729e+303]]
# Iteration 606: [[4.21663700e+302]
#  [3.96997992e+303]
#  [1.21080121e+304]]
# Iteration 607: [[1.33911227e+303]
#  [1.26077934e+304]
#  [3.84524149e+304]]
# Iteration 608: [[4.25272953e+303]
#  [4.00396116e+304]
#  [1.22116512e+305]]
# Iteration 609: [[1.35057447e+304]
#  [1.27157104e+305]
#  [3.87815502e+305]]
# Iteration 610: [[4.28913098e+304]
#  [4.03823326e+305]
#  [1.23161775e+306]]
# Iteration 611: [[1.36213478e+305]
#  [1.28245512e+306]
#  [3.91135029e+306]]
# Iteration 612: [[4.32584400e+305]
#  [4.07279872e+306]
#  [1.24215984e+307]]
# Iteration 613: [[1.37379404e+306]
#  [1.29343236e+307]
#  [3.94482968e+307]]
# Iteration 614: [[4.36287129e+306]
#  [4.10766004e+307]
#  [1.25279217e+308]]
# Iteration 615: [[1.38555310e+307]
#  [1.30450355e+308]
#  [            inf]]
# Iteration 616: [[nan]
#  [inf]
#  [inf]]
# Iteration 617: [[nan]
#  [nan]
#  [nan]]
# Iteration 618: [[nan]
#  [nan]
#  [nan]]
# Iteration 619: [[nan]
#  [nan]
#  [nan]]
# Iteration 620: [[nan]
#  [nan]
#  [nan]]
# Iteration 621: [[nan]
#  [nan]
#  [nan]]
# Iteration 622: [[nan]
#  [nan]
#  [nan]]
# Iteration 623: [[nan]
#  [nan]
#  [nan]]
# Iteration 624: [[nan]
#  [nan]
#  [nan]]
# Iteration 625: [[nan]
#  [nan]
#  [nan]]
# Iteration 626: [[nan]
#  [nan]
#  [nan]]
# Iteration 627: [[nan]
#  [nan]
#  [nan]]
# Iteration 628: [[nan]
#  [nan]
#  [nan]]
# Iteration 629: [[nan]
#  [nan]
#  [nan]]
# Iteration 630: [[nan]
#  [nan]
#  [nan]]
# Iteration 631: [[nan]
#  [nan]
#  [nan]]
# Iteration 632: [[nan]
#  [nan]
#  [nan]]
# Iteration 633: [[nan]
#  [nan]
#  [nan]]
# Iteration 634: [[nan]
#  [nan]
#  [nan]]
# Iteration 635: [[nan]
#  [nan]
#  [nan]]
# Iteration 636: [[nan]
#  [nan]
#  [nan]]
# Iteration 637: [[nan]
#  [nan]
#  [nan]]
# Iteration 638: [[nan]
#  [nan]
#  [nan]]
# Iteration 639: [[nan]
#  [nan]
#  [nan]]
# Iteration 640: [[nan]
#  [nan]
#  [nan]]
# Iteration 641: [[nan]
#  [nan]
#  [nan]]
# Iteration 642: [[nan]
#  [nan]
#  [nan]]
# Iteration 643: [[nan]
#  [nan]
#  [nan]]
# Iteration 644: [[nan]
#  [nan]
#  [nan]]
# Iteration 645: [[nan]
#  [nan]
#  [nan]]
# Iteration 646: [[nan]
#  [nan]
#  [nan]]
# Iteration 647: [[nan]
#  [nan]
#  [nan]]
# Iteration 648: [[nan]
#  [nan]
#  [nan]]
# Iteration 649: [[nan]
#  [nan]
#  [nan]]
# Iteration 650: [[nan]
#  [nan]
#  [nan]]
# Iteration 651: [[nan]
#  [nan]
#  [nan]]
# Iteration 652: [[nan]
#  [nan]
#  [nan]]
# Iteration 653: [[nan]
#  [nan]
#  [nan]]
# Iteration 654: [[nan]
#  [nan]
#  [nan]]
# Iteration 655: [[nan]
#  [nan]
#  [nan]]
# Iteration 656: [[nan]
#  [nan]
#  [nan]]
# Iteration 657: [[nan]
#  [nan]
#  [nan]]
# Iteration 658: [[nan]
#  [nan]
#  [nan]]
# Iteration 659: [[nan]
#  [nan]
#  [nan]]
# Iteration 660: [[nan]
#  [nan]
#  [nan]]
# Iteration 661: [[nan]
#  [nan]
#  [nan]]
# Iteration 662: [[nan]
#  [nan]
#  [nan]]
# Iteration 663: [[nan]
#  [nan]
#  [nan]]
# Iteration 664: [[nan]
#  [nan]
#  [nan]]
# Iteration 665: [[nan]
#  [nan]
#  [nan]]
# Iteration 666: [[nan]
#  [nan]
#  [nan]]
# Iteration 667: [[nan]
#  [nan]
#  [nan]]
# Iteration 668: [[nan]
#  [nan]
#  [nan]]
# Iteration 669: [[nan]
#  [nan]
#  [nan]]
# Iteration 670: [[nan]
#  [nan]
#  [nan]]
# Iteration 671: [[nan]
#  [nan]
#  [nan]]
# Iteration 672: [[nan]
#  [nan]
#  [nan]]
# Iteration 673: [[nan]
#  [nan]
#  [nan]]
# Iteration 674: [[nan]
#  [nan]
#  [nan]]
# Iteration 675: [[nan]
#  [nan]
#  [nan]]
# Iteration 676: [[nan]
#  [nan]
#  [nan]]
# Iteration 677: [[nan]
#  [nan]
#  [nan]]
# Iteration 678: [[nan]
#  [nan]
#  [nan]]
# Iteration 679: [[nan]
#  [nan]
#  [nan]]
# Iteration 680: [[nan]
#  [nan]
#  [nan]]
# Iteration 681: [[nan]
#  [nan]
#  [nan]]
# Iteration 682: [[nan]
#  [nan]
#  [nan]]
# Iteration 683: [[nan]
#  [nan]
#  [nan]]
# Iteration 684: [[nan]
#  [nan]
#  [nan]]
# Iteration 685: [[nan]
#  [nan]
#  [nan]]
# Iteration 686: [[nan]
#  [nan]
#  [nan]]
# Iteration 687: [[nan]
#  [nan]
#  [nan]]
# Iteration 688: [[nan]
#  [nan]
#  [nan]]
# Iteration 689: [[nan]
#  [nan]
#  [nan]]
# Iteration 690: [[nan]
#  [nan]
#  [nan]]
# Iteration 691: [[nan]
#  [nan]
#  [nan]]
# Iteration 692: [[nan]
#  [nan]
#  [nan]]
# Iteration 693: [[nan]
#  [nan]
#  [nan]]
# Iteration 694: [[nan]
#  [nan]
#  [nan]]
# Iteration 695: [[nan]
#  [nan]
#  [nan]]
# Iteration 696: [[nan]
#  [nan]
#  [nan]]
# Iteration 697: [[nan]
#  [nan]
#  [nan]]
# Iteration 698: [[nan]
#  [nan]
#  [nan]]
# Iteration 699: [[nan]
#  [nan]
#  [nan]]
# Iteration 700: [[nan]
#  [nan]
#  [nan]]
# Iteration 701: [[nan]
#  [nan]
#  [nan]]
# Iteration 702: [[nan]
#  [nan]
#  [nan]]
# Iteration 703: [[nan]
#  [nan]
#  [nan]]
# Iteration 704: [[nan]
#  [nan]
#  [nan]]
# Iteration 705: [[nan]
#  [nan]
#  [nan]]
# Iteration 706: [[nan]
#  [nan]
#  [nan]]
# Iteration 707: [[nan]
#  [nan]
#  [nan]]
# Iteration 708: [[nan]
#  [nan]
#  [nan]]
# Iteration 709: [[nan]
#  [nan]
#  [nan]]
# Iteration 710: [[nan]
#  [nan]
#  [nan]]
# Iteration 711: [[nan]
#  [nan]
#  [nan]]
# Iteration 712: [[nan]
#  [nan]
#  [nan]]
# Iteration 713: [[nan]
#  [nan]
#  [nan]]
# Iteration 714: [[nan]
#  [nan]
#  [nan]]
# Iteration 715: [[nan]
#  [nan]
#  [nan]]
# Iteration 716: [[nan]
#  [nan]
#  [nan]]
# Iteration 717: [[nan]
#  [nan]
#  [nan]]
# Iteration 718: [[nan]
#  [nan]
#  [nan]]
# Iteration 719: [[nan]
#  [nan]
#  [nan]]
# Iteration 720: [[nan]
#  [nan]
#  [nan]]
# Iteration 721: [[nan]
#  [nan]
#  [nan]]
# Iteration 722: [[nan]
#  [nan]
#  [nan]]
# Iteration 723: [[nan]
#  [nan]
#  [nan]]
# Iteration 724: [[nan]
#  [nan]
#  [nan]]
# Iteration 725: [[nan]
#  [nan]
#  [nan]]
# Iteration 726: [[nan]
#  [nan]
#  [nan]]
# Iteration 727: [[nan]
#  [nan]
#  [nan]]
# Iteration 728: [[nan]
#  [nan]
#  [nan]]
# Iteration 729: [[nan]
#  [nan]
#  [nan]]
# Iteration 730: [[nan]
#  [nan]
#  [nan]]
# Iteration 731: [[nan]
#  [nan]
#  [nan]]
# Iteration 732: [[nan]
#  [nan]
#  [nan]]
# Iteration 733: [[nan]
#  [nan]
#  [nan]]
# Iteration 734: [[nan]
#  [nan]
#  [nan]]
# Iteration 735: [[nan]
#  [nan]
#  [nan]]
# Iteration 736: [[nan]
#  [nan]
#  [nan]]
# Iteration 737: [[nan]
#  [nan]
#  [nan]]
# Iteration 738: [[nan]
#  [nan]
#  [nan]]
# Iteration 739: [[nan]
#  [nan]
#  [nan]]
# Iteration 740: [[nan]
#  [nan]
#  [nan]]
# Iteration 741: [[nan]
#  [nan]
#  [nan]]
# Iteration 742: [[nan]
#  [nan]
#  [nan]]
# Iteration 743: [[nan]
#  [nan]
#  [nan]]
# Iteration 744: [[nan]
#  [nan]
#  [nan]]
# Iteration 745: [[nan]
#  [nan]
#  [nan]]
# Iteration 746: [[nan]
#  [nan]
#  [nan]]
# Iteration 747: [[nan]
#  [nan]
#  [nan]]
# Iteration 748: [[nan]
#  [nan]
#  [nan]]
# Iteration 749: [[nan]
#  [nan]
#  [nan]]
# Iteration 750: [[nan]
#  [nan]
#  [nan]]
# Iteration 751: [[nan]
#  [nan]
#  [nan]]
# Iteration 752: [[nan]
#  [nan]
#  [nan]]
# Iteration 753: [[nan]
#  [nan]
#  [nan]]
# Iteration 754: [[nan]
#  [nan]
#  [nan]]
# Iteration 755: [[nan]
#  [nan]
#  [nan]]
# Iteration 756: [[nan]
#  [nan]
#  [nan]]
# Iteration 757: [[nan]
#  [nan]
#  [nan]]
# Iteration 758: [[nan]
#  [nan]
#  [nan]]
# Iteration 759: [[nan]
#  [nan]
#  [nan]]
# Iteration 760: [[nan]
#  [nan]
#  [nan]]
# Iteration 761: [[nan]
#  [nan]
#  [nan]]
# Iteration 762: [[nan]
#  [nan]
#  [nan]]
# Iteration 763: [[nan]
#  [nan]
#  [nan]]
# Iteration 764: [[nan]
#  [nan]
#  [nan]]
# Iteration 765: [[nan]
#  [nan]
#  [nan]]
# Iteration 766: [[nan]
#  [nan]
#  [nan]]
# Iteration 767: [[nan]
#  [nan]
#  [nan]]
# Iteration 768: [[nan]
#  [nan]
#  [nan]]
# Iteration 769: [[nan]
#  [nan]
#  [nan]]
# Iteration 770: [[nan]
#  [nan]
#  [nan]]
# Iteration 771: [[nan]
#  [nan]
#  [nan]]
# Iteration 772: [[nan]
#  [nan]
#  [nan]]
# Iteration 773: [[nan]
#  [nan]
#  [nan]]
# Iteration 774: [[nan]
#  [nan]
#  [nan]]
# Iteration 775: [[nan]
#  [nan]
#  [nan]]
# Iteration 776: [[nan]
#  [nan]
#  [nan]]
# Iteration 777: [[nan]
#  [nan]
#  [nan]]
# Iteration 778: [[nan]
#  [nan]
#  [nan]]
# Iteration 779: [[nan]
#  [nan]
#  [nan]]
# Iteration 780: [[nan]
#  [nan]
#  [nan]]
# Iteration 781: [[nan]
#  [nan]
#  [nan]]
# Iteration 782: [[nan]
#  [nan]
#  [nan]]
# Iteration 783: [[nan]
#  [nan]
#  [nan]]
# Iteration 784: [[nan]
#  [nan]
#  [nan]]
# Iteration 785: [[nan]
#  [nan]
#  [nan]]
# Iteration 786: [[nan]
#  [nan]
#  [nan]]
# Iteration 787: [[nan]
#  [nan]
#  [nan]]
# Iteration 788: [[nan]
#  [nan]
#  [nan]]
# Iteration 789: [[nan]
#  [nan]
#  [nan]]
# Iteration 790: [[nan]
#  [nan]
#  [nan]]
# Iteration 791: [[nan]
#  [nan]
#  [nan]]
# Iteration 792: [[nan]
#  [nan]
#  [nan]]
# Iteration 793: [[nan]
#  [nan]
#  [nan]]
# Iteration 794: [[nan]
#  [nan]
#  [nan]]
# Iteration 795: [[nan]
#  [nan]
#  [nan]]
# Iteration 796: [[nan]
#  [nan]
#  [nan]]
# Iteration 797: [[nan]
#  [nan]
#  [nan]]
# Iteration 798: [[nan]
#  [nan]
#  [nan]]
# Iteration 799: [[nan]
#  [nan]
#  [nan]]
# Iteration 800: [[nan]
#  [nan]
#  [nan]]
# Iteration 801: [[nan]
#  [nan]
#  [nan]]
# Iteration 802: [[nan]
#  [nan]
#  [nan]]
# Iteration 803: [[nan]
#  [nan]
#  [nan]]
# Iteration 804: [[nan]
#  [nan]
#  [nan]]
# Iteration 805: [[nan]
#  [nan]
#  [nan]]
# Iteration 806: [[nan]
#  [nan]
#  [nan]]
# Iteration 807: [[nan]
#  [nan]
#  [nan]]
# Iteration 808: [[nan]
#  [nan]
#  [nan]]
# Iteration 809: [[nan]
#  [nan]
#  [nan]]
# Iteration 810: [[nan]
#  [nan]
#  [nan]]
# Iteration 811: [[nan]
#  [nan]
#  [nan]]
# Iteration 812: [[nan]
#  [nan]
#  [nan]]
# Iteration 813: [[nan]
#  [nan]
#  [nan]]
# Iteration 814: [[nan]
#  [nan]
#  [nan]]
# Iteration 815: [[nan]
#  [nan]
#  [nan]]
# Iteration 816: [[nan]
#  [nan]
#  [nan]]
# Iteration 817: [[nan]
#  [nan]
#  [nan]]
# Iteration 818: [[nan]
#  [nan]
#  [nan]]
# Iteration 819: [[nan]
#  [nan]
#  [nan]]
# Iteration 820: [[nan]
#  [nan]
#  [nan]]
# Iteration 821: [[nan]
#  [nan]
#  [nan]]
# Iteration 822: [[nan]
#  [nan]
#  [nan]]
# Iteration 823: [[nan]
#  [nan]
#  [nan]]
# Iteration 824: [[nan]
#  [nan]
#  [nan]]<ipython-input-19-c6ae30a5098d>:20: RuntimeWarning: overflow encountered in true_divide
#   x_new[i] = (b[i] - s1 - s2) / AA[i, i]
#
# Iteration 825: [[nan]
#  [nan]
#  [nan]]
# Iteration 826: [[nan]
#  [nan]
#  [nan]]
# Iteration 827: [[nan]
#  [nan]
#  [nan]]
# Iteration 828: [[nan]
#  [nan]
#  [nan]]
# Iteration 829: [[nan]
#  [nan]
#  [nan]]
# Iteration 830: [[nan]
#  [nan]
#  [nan]]
# Iteration 831: [[nan]
#  [nan]
#  [nan]]
# Iteration 832: [[nan]
#  [nan]
#  [nan]]
# Iteration 833: [[nan]
#  [nan]
#  [nan]]
# Iteration 834: [[nan]
#  [nan]
#  [nan]]
# Iteration 835: [[nan]
#  [nan]
#  [nan]]
# Iteration 836: [[nan]
#  [nan]
#  [nan]]
# Iteration 837: [[nan]
#  [nan]
#  [nan]]
# Iteration 838: [[nan]
#  [nan]
#  [nan]]
# Iteration 839: [[nan]
#  [nan]
#  [nan]]
# Iteration 840: [[nan]
#  [nan]
#  [nan]]
# Iteration 841: [[nan]
#  [nan]
#  [nan]]
# Iteration 842: [[nan]
#  [nan]
#  [nan]]
# Iteration 843: [[nan]
#  [nan]
#  [nan]]
# Iteration 844: [[nan]
#  [nan]
#  [nan]]
# Iteration 845: [[nan]
#  [nan]
#  [nan]]
# Iteration 846: [[nan]
#  [nan]
#  [nan]]
# Iteration 847: [[nan]
#  [nan]
#  [nan]]
# Iteration 848: [[nan]
#  [nan]
#  [nan]]
# Iteration 849: [[nan]
#  [nan]
#  [nan]]
# Iteration 850: [[nan]
#  [nan]
#  [nan]]
# Iteration 851: [[nan]
#  [nan]
#  [nan]]
# Iteration 852: [[nan]
#  [nan]
#  [nan]]
# Iteration 853: [[nan]
#  [nan]
#  [nan]]
# Iteration 854: [[nan]
#  [nan]
#  [nan]]
# Iteration 855: [[nan]
#  [nan]
#  [nan]]
# Iteration 856: [[nan]
#  [nan]
#  [nan]]
# Iteration 857: [[nan]
#  [nan]
#  [nan]]
# Iteration 858: [[nan]
#  [nan]
#  [nan]]
# Iteration 859: [[nan]
#  [nan]
#  [nan]]
# Iteration 860: [[nan]
#  [nan]
#  [nan]]
# Iteration 861: [[nan]
#  [nan]
#  [nan]]
# Iteration 862: [[nan]
#  [nan]
#  [nan]]
# Iteration 863: [[nan]
#  [nan]
#  [nan]]
# Iteration 864: [[nan]
#  [nan]
#  [nan]]
# Iteration 865: [[nan]
#  [nan]
#  [nan]]
# Iteration 866: [[nan]
#  [nan]
#  [nan]]
# Iteration 867: [[nan]
#  [nan]
#  [nan]]
# Iteration 868: [[nan]
#  [nan]
#  [nan]]
# Iteration 869: [[nan]
#  [nan]
#  [nan]]
# Iteration 870: [[nan]
#  [nan]
#  [nan]]
# Iteration 871: [[nan]
#  [nan]
#  [nan]]
# Iteration 872: [[nan]
#  [nan]
#  [nan]]
# Iteration 873: [[nan]
#  [nan]
#  [nan]]
# Iteration 874: [[nan]
#  [nan]
#  [nan]]
# Iteration 875: [[nan]
#  [nan]
#  [nan]]
# Iteration 876: [[nan]
#  [nan]
#  [nan]]
# Iteration 877: [[nan]
#  [nan]
#  [nan]]
# Iteration 878: [[nan]
#  [nan]
#  [nan]]
# Iteration 879: [[nan]
#  [nan]
#  [nan]]
# Iteration 880: [[nan]
#  [nan]
#  [nan]]
# Iteration 881: [[nan]
#  [nan]
#  [nan]]
# Iteration 882: [[nan]
#  [nan]
#  [nan]]
# Iteration 883: [[nan]
#  [nan]
#  [nan]]
# Iteration 884: [[nan]
#  [nan]
#  [nan]]
# Iteration 885: [[nan]
#  [nan]
#  [nan]]
# Iteration 886: [[nan]
#  [nan]
#  [nan]]
# Iteration 887: [[nan]
#  [nan]
#  [nan]]
# Iteration 888: [[nan]
#  [nan]
#  [nan]]
# Iteration 889: [[nan]
#  [nan]
#  [nan]]
# Iteration 890: [[nan]
#  [nan]
#  [nan]]
# Iteration 891: [[nan]
#  [nan]
#  [nan]]
# Iteration 892: [[nan]
#  [nan]
#  [nan]]
# Iteration 893: [[nan]
#  [nan]
#  [nan]]
# Iteration 894: [[nan]
#  [nan]
#  [nan]]
# Iteration 895: [[nan]
#  [nan]
#  [nan]]
# Iteration 896: [[nan]
#  [nan]
#  [nan]]
# Iteration 897: [[nan]
#  [nan]
#  [nan]]
# Iteration 898: [[nan]
#  [nan]
#  [nan]]
# Iteration 899: [[nan]
#  [nan]
#  [nan]]
# Iteration 900: [[nan]
#  [nan]
#  [nan]]
# Iteration 901: [[nan]
#  [nan]
#  [nan]]
# Iteration 902: [[nan]
#  [nan]
#  [nan]]
# Iteration 903: [[nan]
#  [nan]
#  [nan]]
# Iteration 904: [[nan]
#  [nan]
#  [nan]]
# Iteration 905: [[nan]
#  [nan]
#  [nan]]
# Iteration 906: [[nan]
#  [nan]
#  [nan]]
# Iteration 907: [[nan]
#  [nan]
#  [nan]]
# Iteration 908: [[nan]
#  [nan]
#  [nan]]
# Iteration 909: [[nan]
#  [nan]
#  [nan]]
# Iteration 910: [[nan]
#  [nan]
#  [nan]]
# Iteration 911: [[nan]
#  [nan]
#  [nan]]
# Iteration 912: [[nan]
#  [nan]
#  [nan]]
# Iteration 913: [[nan]
#  [nan]
#  [nan]]
# Iteration 914: [[nan]
#  [nan]
#  [nan]]
# Iteration 915: [[nan]
#  [nan]
#  [nan]]
# Iteration 916: [[nan]
#  [nan]
#  [nan]]
# Iteration 917: [[nan]
#  [nan]
#  [nan]]
# Iteration 918: [[nan]
#  [nan]
#  [nan]]
# Iteration 919: [[nan]
#  [nan]
#  [nan]]
# Iteration 920: [[nan]
#  [nan]
#  [nan]]
# Iteration 921: [[nan]
#  [nan]
#  [nan]]
# Iteration 922: [[nan]
#  [nan]
#  [nan]]
# Iteration 923: [[nan]
#  [nan]
#  [nan]]
# Iteration 924: [[nan]
#  [nan]
#  [nan]]
# Iteration 925: [[nan]
#  [nan]
#  [nan]]
# Iteration 926: [[nan]
#  [nan]
#  [nan]]
# Iteration 927: [[nan]
#  [nan]
#  [nan]]
# Iteration 928: [[nan]
#  [nan]
#  [nan]]
# Iteration 929: [[nan]
#  [nan]
#  [nan]]
# Iteration 930: [[nan]
#  [nan]
#  [nan]]
# Iteration 931: [[nan]
#  [nan]
#  [nan]]
# Iteration 932: [[nan]
#  [nan]
#  [nan]]
# Iteration 933: [[nan]
#  [nan]
#  [nan]]
# Iteration 934: [[nan]
#  [nan]
#  [nan]]
# Iteration 935: [[nan]
#  [nan]
#  [nan]]
# Iteration 936: [[nan]
#  [nan]
#  [nan]]
# Iteration 937: [[nan]
#  [nan]
#  [nan]]
# Iteration 938: [[nan]
#  [nan]
#  [nan]]
# Iteration 939: [[nan]
#  [nan]
#  [nan]]
# Iteration 940: [[nan]
#  [nan]
#  [nan]]
# Iteration 941: [[nan]
#  [nan]
#  [nan]]
# Iteration 942: [[nan]
#  [nan]
#  [nan]]
# Iteration 943: [[nan]
#  [nan]
#  [nan]]
# Iteration 944: [[nan]
#  [nan]
#  [nan]]
# Iteration 945: [[nan]
#  [nan]
#  [nan]]
# Iteration 946: [[nan]
#  [nan]
#  [nan]]
# Iteration 947: [[nan]
#  [nan]
#  [nan]]
# Iteration 948: [[nan]
#  [nan]
#  [nan]]
# Iteration 949: [[nan]
#  [nan]
#  [nan]]
# Iteration 950: [[nan]
#  [nan]
#  [nan]]
# Iteration 951: [[nan]
#  [nan]
#  [nan]]
# Iteration 952: [[nan]
#  [nan]
#  [nan]]
# Iteration 953: [[nan]
#  [nan]
#  [nan]]
# Iteration 954: [[nan]
#  [nan]
#  [nan]]
# Iteration 955: [[nan]
#  [nan]
#  [nan]]
# Iteration 956: [[nan]
#  [nan]
#  [nan]]
# Iteration 957: [[nan]
#  [nan]
#  [nan]]
# Iteration 958: [[nan]
#  [nan]
#  [nan]]
# Iteration 959: [[nan]
#  [nan]
#  [nan]]
# Iteration 960: [[nan]
#  [nan]
#  [nan]]
# Iteration 961: [[nan]
#  [nan]
#  [nan]]
# Iteration 962: [[nan]
#  [nan]
#  [nan]]
# Iteration 963: [[nan]
#  [nan]
#  [nan]]
# Iteration 964: [[nan]
#  [nan]
#  [nan]]
# Iteration 965: [[nan]
#  [nan]
#  [nan]]
# Iteration 966: [[nan]
#  [nan]
#  [nan]]
# Iteration 967: [[nan]
#  [nan]
#  [nan]]
# Iteration 968: [[nan]
#  [nan]
#  [nan]]
# Iteration 969: [[nan]
#  [nan]
#  [nan]]
# Iteration 970: [[nan]
#  [nan]
#  [nan]]
# Iteration 971: [[nan]
#  [nan]
#  [nan]]
# Iteration 972: [[nan]
#  [nan]
#  [nan]]
# Iteration 973: [[nan]
#  [nan]
#  [nan]]
# Iteration 974: [[nan]
#  [nan]
#  [nan]]
# Iteration 975: [[nan]
#  [nan]
#  [nan]]
# Iteration 976: [[nan]
#  [nan]
#  [nan]]
# Iteration 977: [[nan]
#  [nan]
#  [nan]]
# Iteration 978: [[nan]
#  [nan]
#  [nan]]
# Iteration 979: [[nan]
#  [nan]
#  [nan]]
# Iteration 980: [[nan]
#  [nan]
#  [nan]]
# Iteration 981: [[nan]
#  [nan]
#  [nan]]
# Iteration 982: [[nan]
#  [nan]
#  [nan]]
# Iteration 983: [[nan]
#  [nan]
#  [nan]]
# Iteration 984: [[nan]
#  [nan]
#  [nan]]
# Iteration 985: [[nan]
#  [nan]
#  [nan]]
# Iteration 986: [[nan]
#  [nan]
#  [nan]]
# Iteration 987: [[nan]
#  [nan]
#  [nan]]
# Iteration 988: [[nan]
#  [nan]
#  [nan]]
# Iteration 989: [[nan]
#  [nan]
#  [nan]]
# Iteration 990: [[nan]
#  [nan]
#  [nan]]
# Iteration 991: [[nan]
#  [nan]
#  [nan]]
# Iteration 992: [[nan]
#  [nan]
#  [nan]]
# Iteration 993: [[nan]
#  [nan]
#  [nan]]
# Iteration 994: [[nan]
#  [nan]
#  [nan]]
# Iteration 995: [[nan]
#  [nan]
#  [nan]]
# Iteration 996: [[nan]
#  [nan]
#  [nan]]
# Iteration 997: [[nan]
#  [nan]
#  [nan]]
# Iteration 998: [[nan]
#  [nan]
#  [nan]]
# Iteration 999: [[nan]
#  [nan]
#  [nan]]
# Solution:
# [[nan]
#  [nan]
#  [nan]]
# Error:
# [[nan]
#  [nan]
#  [nan]]
